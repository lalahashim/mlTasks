# %%
import pandas as pd

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 1. Handle missing values. Encode categorical variables

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["gender"].replace(["Male", "Female"], [0, 1], inplace=True)
df["gender"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3591724202.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["gender"].replace(["Male", "Female"], [0, 1], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3591724202.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["gender"].replace(["Male", "Female"], [0, 1], inplace=True)
# array([1, 0])

# %%
df["Partner"].replace(["No", "Yes"], [0, 1], inplace=True)
df["Partner"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2958215146.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Partner"].replace(["No", "Yes"], [0, 1], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2958215146.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Partner"].replace(["No", "Yes"], [0, 1], inplace=True)
# array([1, 0])

# %%
df["Dependents"].replace(["No", "Yes"], [0, 1], inplace=True)
df["Dependents"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\26684954.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Dependents"].replace(["No", "Yes"], [0, 1], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\26684954.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Dependents"].replace(["No", "Yes"], [0, 1], inplace=True)
# array([0, 1])

# %%
df["PhoneService"].replace(["No", "Yes"], [0, 1], inplace=True)
df["PhoneService"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2483157992.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PhoneService"].replace(["No", "Yes"], [0, 1], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2483157992.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["PhoneService"].replace(["No", "Yes"], [0, 1], inplace=True)
# array([0, 1])

# %%
df["MultipleLines"].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df["MultipleLines"].replace(["No phone service", "No", "Yes"], [0, 1, 2], inplace=True)
df["MultipleLines"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\582562786.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["MultipleLines"].replace(["No phone service", "No", "Yes"], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\582562786.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["MultipleLines"].replace(["No phone service", "No", "Yes"], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["InternetService"].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df["InternetService"].replace(['No', 'DSL', 'Fiber optic'], [0, 1, 2], inplace=True)
df["InternetService"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2890032190.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["InternetService"].replace(['No', 'DSL', 'Fiber optic'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2890032190.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["InternetService"].replace(['No', 'DSL', 'Fiber optic'], [0, 1, 2], inplace=True)
# array([1, 2, 0])

# %%
df["OnlineSecurity"].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df["OnlineSecurity"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["OnlineSecurity"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3471370457.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["OnlineSecurity"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3471370457.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["OnlineSecurity"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["OnlineBackup"].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df["OnlineBackup"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["OnlineBackup"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\46249985.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["OnlineBackup"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\46249985.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["OnlineBackup"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([1, 0, 2])

# %%
df["DeviceProtection"].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df["DeviceProtection"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["DeviceProtection"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\1826992489.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["DeviceProtection"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\1826992489.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["DeviceProtection"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["TechSupport"].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df["TechSupport"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["TechSupport"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\964551935.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["TechSupport"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\964551935.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["TechSupport"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["StreamingTV"].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df["StreamingTV"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["StreamingTV"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\214397022.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["StreamingTV"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\214397022.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["StreamingTV"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["StreamingMovies"].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df["StreamingMovies"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
df["StreamingMovies"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\4113958729.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["StreamingMovies"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\4113958729.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["StreamingMovies"].replace(['No', 'Yes', 'No internet service'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["Contract"].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df["Contract"].replace(['Month-to-month', 'One year', 'Two year'], [0, 1, 2], inplace=True)
df["Contract"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2401919643.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Contract"].replace(['Month-to-month', 'One year', 'Two year'], [0, 1, 2], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\2401919643.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Contract"].replace(['Month-to-month', 'One year', 'Two year'], [0, 1, 2], inplace=True)
# array([0, 1, 2])

# %%
df["PaperlessBilling"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["PaperlessBilling"].replace(["No", "Yes"], [0, 1], inplace=True)
df["PaperlessBilling"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3333649943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PaperlessBilling"].replace(["No", "Yes"], [0, 1], inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3333649943.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["PaperlessBilling"].replace(["No", "Yes"], [0, 1], inplace=True)
# array([1, 0])

# %%
df["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df["PaymentMethod"].replace(['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)'],
                            [0, 1, 2, 3], inplace=True)
df["PaymentMethod"].unique()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3521716125.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PaymentMethod"].replace(['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)'],
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5312\3521716125.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["PaymentMethod"].replace(['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)'],
# array([0, 1, 2, 3])

# %%
df["TotalCharges"].unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   int64
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(17), object(2)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### 2. Train-test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(columns=["customerID", "Churn"])
y = df["Churn"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 3. Select classification algorithms (choose at least three). Use GridSearchCV or RandomizedSearchCV (scoring: both accuracy and f1 score)

# %%
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier 
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
bagging = BaggingClassifier(estimator=LogisticRegression(max_iter=1000), n_estimators=10, random_state=42).fit(X_train_scaled, y_train)
y_pred_train_bc = bagging.predict(X_train_scaled)
y_pred_test_bc = bagging.predict(X_test_scaled)
print("Classification Report (Train Set):\n", classification_report(y_train, y_pred_train_bc))
print("\nClassification Report (Test Set):\n", classification_report(y_test, y_pred_test_bc))
# Out:
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#           No       0.85      0.90      0.87      4130
#          Yes       0.66      0.55      0.60      1495
#
#     accuracy                           0.81      5625
#    macro avg       0.76      0.73      0.74      5625
# weighted avg       0.80      0.81      0.80      5625
#
#
# Classification Report (Test Set):
#                precision    recall  f1-score   support
#
#           No       0.85      0.88      0.86      1033
#          Yes       0.63      0.56      0.59       374
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.72      0.73      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
lr = LogisticRegression(max_iter=1000, random_state=42).fit(X_train_scaled, y_train)
y_train_pr_lr = lr.predict(X_train_scaled)
y_test_pr_lr = lr.predict(X_test_scaled)
print("Test:\n", classification_report(y_test, y_test_pr_lr))
print("Train:\n", classification_report(y_train, y_train_pr_lr))
# Out:
# Test:
#                precision    recall  f1-score   support
#
#           No       0.85      0.88      0.87      1033
#          Yes       0.63      0.57      0.60       374
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.72      0.73      1407
# weighted avg       0.79      0.80      0.79      1407
#
# Train:
#                precision    recall  f1-score   support
#
#           No       0.85      0.90      0.87      4130
#          Yes       0.66      0.56      0.60      1495
#
#     accuracy                           0.80      5625
#    macro avg       0.75      0.73      0.74      5625
# weighted avg       0.80      0.80      0.80      5625

# %%
svc = SVC(probability=True, random_state=42)
nb_clf = GaussianNB()

lr_pipe = Pipeline([("scaler", StandardScaler()), ("lr", lr)])
svc_pipe = Pipeline([("scaler", StandardScaler()), ("svc", svc)])
nb_pipe = Pipeline([("scaler", StandardScaler()), ("nb", nb_clf)])

voting_clf = VotingClassifier(
    estimators=[('log', lr_pipe), ('svm', svc_pipe), ('nb', nb_pipe)],
    voting='soft',
    weights=[1,3,1]
)
voting_clf.fit(X_train, y_train)
y_pred_train_vc = voting_clf.predict(X_train)
y_pred_test_vc = voting_clf.predict(X_test)

print("Classification Report (Train Set):\n", classification_report(y_train, y_pred_train_vc))
print("\nClassification Report (Test Set):\n", classification_report(y_test, y_pred_test_vc))
# Out:
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#           No       0.86      0.90      0.88      4130
#          Yes       0.68      0.59      0.63      1495
#
#     accuracy                           0.82      5625
#    macro avg       0.77      0.74      0.75      5625
# weighted avg       0.81      0.82      0.81      5625
#
#
# Classification Report (Test Set):
#                precision    recall  f1-score   support
#
#           No       0.85      0.87      0.86      1033
#          Yes       0.62      0.58      0.60       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.73      0.73      1407
# weighted avg       0.79      0.79      0.79      1407

# %%
param_grid = {
    "C": [0.1, 1, 10],
    "gamma": [0.01, 0.1, 1]
}

grid = GridSearchCV(
    SVC(),
    param_grid=param_grid,
    cv=5,
    scoring="accuracy"
).fit(X_train, y_train)

y_pred_train_grid = voting_clf.predict(X_train)
y_pred_test_grid = voting_clf.predict(X_test)

print("Classification Report (Train Set):\n", classification_report(y_train, y_pred_train_grid))
print("\nClassification Report (Test Set):\n", classification_report(y_test, y_pred_test_grid))
# Out:
# Classification Report (Train Set):
#                precision    recall  f1-score   support
#
#           No       0.86      0.90      0.88      4130
#          Yes       0.68      0.59      0.63      1495
#
#     accuracy                           0.82      5625
#    macro avg       0.77      0.74      0.75      5625
# weighted avg       0.81      0.82      0.81      5625
#
#
# Classification Report (Test Set):
#                precision    recall  f1-score   support
#
#           No       0.85      0.87      0.86      1033
#          Yes       0.62      0.58      0.60       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.73      0.73      1407
# weighted avg       0.79      0.79      0.79      1407
